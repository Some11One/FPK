# %%
import codecs
import lxml
from lxml import etree
import os
from mmap import mmap
import re
from os import listdir
from os.path import isfile, join
import MySQLdb
from datetime import datetime

# %%
class RootClass(object):
    """docstring"""
    
    def __init__(self, code, seatsAvail, authLevel, resHoldTotal):
        """Constructor"""
        self.code = code
        self.seatsAvail = seatsAvail
        self.authLevel = authLevel
        self.resHoldTotal = resHoldTotal
        
class Cabin(object):
    """docstring"""
    
    def __init__(self, rootClass, code, resHoldTotal, capacity, seatsAvail, allotment):
        """Constructor"""
        self.rootClass = rootClass
        self.code = code
        self.resHoldTotal = resHoldTotal
        self.capacity = capacity
        self.seatsAvail = seatsAvail
        self.allotment = allotment
        
class Leg(object):
    """docstring"""
    
    def __init__(self, cabins, dptDt, dptTime, arrDt, arrTime, orig, dest):
        """Constructor"""
        self.cabins = cabins
        self.dptDt = dptDt
        self.dptTime = dptTime
        self.arrDt = arrDt
        self.arrTime = arrTime
        self.orig = orig
        self.dest = dest
        
class SegCabin(object):
    """docstring"""
    
    def __init__(self, rootClass, code):
        """Constructor"""
        self.rootClass = rootClass
        self.code = code
        
class Segment(object):
    """docstring"""
    
    def __init__(self, segCabins, dptDt, orig, dest):
        """Constructor"""
        self.segCabins = segCabins
        self.dptDt = dptDt
        self.orig = orig
        self.dest = dest
        
class FlightId(object):
    """docstring"""
    
    def __init__(self, carrier, fltNr, opsSuffix, fltNrDptDt, fltNrArrDt):
        """Constructor"""
        self.carrier = carrier
        self.fltNr = fltNr
        self.opsSuffix = opsSuffix
        self.fltNrDptDt = fltNrDptDt
        self.fltNrArrDt = fltNrArrDt
        
class Flight(object):
    """docstring"""
    
    def __init__(self, flightId, legs, segments):
        """Constructor"""
        self.flightId = flightId
        self.legs = legs    
        self.segments = segments

# %%
def fast_iter(context, func, *args, **kwargs):
    for event, elem in iter(context):
        func(event, elem, *args, **kwargs)
        elem.clear()
        for ancestor in elem.xpath('ancestor-or-self::*'):
            while ancestor.getprevious() is not None:
                del ancestor.getparent()[0]
    del context

# %%
def process_element(event, elem):
    if elem.tag == '{' + elem.nsmap.get(None) + '}FlightId' and elem.attrib.get('fltNr') + elem.attrib.get('opsSuffix') in fltNrs:
        flightId = FlightId(fltNrDptDt=elem.attrib.get('fltNrDptDt'), fltNrArrDt=elem.attrib.get('fltNrArrDt'), carrier=elem.attrib.get('carrier'), fltNr=elem.attrib.get('fltNr'),  opsSuffix=elem.attrib.get('opsSuffix'))
        
        legs = list()
        for leg in elem.getparent().findall('{' + elem.getparent().nsmap.get(None) + '}Leg'):
            cabins = list()
            for cabin in leg.findall('{' + leg.nsmap.get(None) + '}Cabin'):
                rootClassElem = cabin.find('{' + cabin.nsmap.get(None) + '}RootClass')
                if rootClassElem is not None:
                    rootClass = RootClass(code=rootClassElem.attrib.get('code'), seatsAvail=rootClassElem.attrib.get('seatsAvail'),authLevel=rootClassElem.attrib.get('authLevel'),resHoldTotal=rootClassElem.attrib.get('resHoldTotal'))
                    cabins.append(Cabin(rootClass=rootClass, code = cabin.attrib.get('code'),  resHoldTotal = cabin.attrib.get('resHoldTotal'), capacity = cabin.attrib.get('capacity'), seatsAvail = cabin.attrib.get('seatsAvail'), allotment = cabin.attrib.get('allotment')))
                else:
                    cabins.append(Cabin(rootClass=None, code = cabin.attrib.get('code'),  resHoldTotal = cabin.attrib.get('resHoldTotal'), capacity = cabin.attrib.get('capacity'), seatsAvail = cabin.attrib.get('seatsAvail'), allotment = cabin.attrib.get('allotment')))
            legs.append(Leg(cabins=cabins, arrDt=leg.attrib.get('arrDt'), dest=leg.attrib.get('dest'), dptTime=leg.attrib.get('dptTime'), arrTime=leg.attrib.get('arrTime'), dptDt=leg.attrib.get('dptDt'), orig=leg.attrib.get('orig')))

        segs = list()
        for seg in elem.getparent().findall('{' + elem.getparent().nsmap.get(None) + '}Segment'):
            cabins = list()
            for cabin in seg.findall('{' + seg.nsmap.get(None) + '}Cabin'):
                rootClassElem = cabin.find('{' + cabin.nsmap.get(None) + '}RootClass')
                if rootClassElem is not None:
                    rootClass = RootClass(code=rootClassElem.attrib.get('code'), seatsAvail=rootClassElem.attrib.get('seatsAvail'),authLevel=rootClassElem.attrib.get('authLevel'),resHoldTotal=rootClassElem.attrib.get('resHoldTotal'))
                    cabins.append(SegCabin(rootClass=rootClass, code = cabin.attrib.get('code')))
                else:
                    cabins.append(SegCabin(rootClass=None,  code = cabin.attrib.get('code')))
            segs.append(Segment(segCabins=cabins, dest=seg.attrib.get('dest'), dptDt=seg.attrib.get('dptDt'), orig=seg.attrib.get('orig')))

        proccess_flight(Flight(flightId=flightId, legs=legs, segments=segs) )

# %%
def proccess_flight(flight):
    
    # day timestamp
    reportDt = inventory_file.split("_")[1].split(".")[0]
    
    # insert flight
    cur.execute("INSERT INTO Flight(Carrier, fltNr, opsSuffix, fltNrDptDt, fltNrArrDt) VALUES(%s, %s, %s, %s, %s)", 
                (flight.flightId.carrier, int(flight.flightId.fltNr), flight.flightId.opsSuffix, 
                 datetime.strptime(flight.flightId.fltNrDptDt, "%d%m%y").date(), datetime.strptime(flight.flightId.fltNrArrDt, "%d%m%y").date()))
    flightId = cur.lastrowid
    
    # insert legs
    for leg in flight.legs:
        cur.execute("INSERT INTO Leg(DptDt, DptTime, ArrDt, ArrTime, orig, dest, fkFlightID) VALUES(%s, %s, %s, %s, %s, %s, %s)",
                (datetime.strptime(leg.dptDt, "%d%m%y").date(), datetime.strptime(leg.dptTime, "%H%M").time(), 
                 datetime.strptime(leg.arrDt, "%d%m%y").date(), datetime.strptime(leg.arrTime, "%H%M").time(),
                 leg.orig, leg.dest, int(flightId)))
        legId = cur.lastrowid
        
        # insert cabins
        for cabin in leg.cabins:
            cur.execute("INSERT INTO Cabin(Code, resHoldTotal, capacity, seatsAvail, allotment, fkLegID) VALUES(%s, %s, %s, %s, %s, %s)", 
                (cabin.code, float(cabin.resHoldTotal), int(cabin.capacity), int(cabin.seatsAvail), float(cabin.allotment), int(legId)))
            cabinId = cur.lastrowid
            
            # insert root if any
            if (cabin.rootClass != None):
                cur.execute("INSERT INTO RootClass(Code, seatsAvail, authLevel, resHoldTotal, fkCabinID, reportDt) VALUES(%s, %s, %s, %s, %s, %s)", 
                    (cabin.rootClass.code, int(cabin.rootClass.seatsAvail), 
                     float(cabin.rootClass.authLevel), float(cabin.rootClass.resHoldTotal), int(cabinId), datetime.strptime(reportDt, "%Y%m%d").date()))
            
    # insert segments
    for seg in flight.segments:
        cur.execute("INSERT INTO Segment(orig, dest, DptDt, fkFlightID) VALUES(%s, %s, %s, %s)", 
                (seg.orig, seg.dest, datetime.strptime(seg.dptDt, "%d%m%y").date(), int(flightId)))
        segId = cur.lastrowid

        # insert seg cabins
        for segCabin in seg.segCabins:
            cur.execute("INSERT INTO SegCabin(Code, fkSegmentID) VALUES(%s, %s)", 
                (segCabin.code, int(segId)))
            segCabinId = cur.lastrowid

            # insert root if any
            if (segCabin.rootClass != None):
                cur.execute("INSERT INTO RootClass(Code, seatsAvail, authLevel, resHoldTotal, fkSegCabinID, reportDt) VALUES(%s, %s, %s, %s, %s, %s)", 
                    (segCabin.rootClass.code, int(segCabin.rootClass.seatsAvail), 
                     float(segCabin.rootClass.authLevel), float(segCabin.rootClass.resHoldTotal), int(segCabinId), datetime.strptime(reportDt, "%Y%m%d").date()))

# %%
fltNrs = ('88J', '87J','102J', '101J', '337J', '337ZH', '50M', '49J', '10J', '9J', '138J', '137YQ')
db = MySQLdb.connect(host="194.247.15.117", 
                     port=7806,
                     user="bar",
                     passwd="PASSWORD",
                     db="Inventory")

inventory_path = '../data/backup/PROD/data/rm-in'
for inventory_file in [f for f in listdir(inventory_path) if isfile(join(inventory_path, f))]:
    if inventory_file.endswith('.xml'):
        db.autocommit(True) 
        cur = db.cursor()
        context = etree.iterparse(inventory_path + '/' + inventory_file)
        fast_iter(context, process_element)
        print(inventory_file + ' loading into db complete ' + str(datetime.now()))
        # db.close()
        cur.close()
# Out:
# inventory_20150301.xml loading into db complete 2017-07-13 10:53:58.208617
# inventory_20150302.xml loading into db complete 2017-07-13 10:58:16.138214
# inventory_20150303.xml loading into db complete 2017-07-13 11:02:39.080074
# inventory_20150304.xml loading into db complete 2017-07-13 11:06:38.942820
# inventory_20150305.xml loading into db complete 2017-07-13 11:10:51.598718
# inventory_20150306.xml loading into db complete 2017-07-13 11:15:00.605688
# inventory_20150307.xml loading into db complete 2017-07-13 11:19:12.499018
# inventory_20150308.xml loading into db complete 2017-07-13 11:23:28.802124
# inventory_20150309.xml loading into db complete 2017-07-13 11:27:41.091070
# inventory_20150310.xml loading into db complete 2017-07-13 11:31:46.813957
# inventory_20150311.xml loading into db complete 2017-07-13 11:35:57.826802
# inventory_20150312.xml loading into db complete 2017-07-13 11:40:21.719545
# inventory_20150313.xml loading into db complete 2017-07-13 11:44:40.381927
# inventory_20150314.xml loading into db complete 2017-07-13 11:48:54.782904
# inventory_20150315.xml loading into db complete 2017-07-13 11:53:09.390896
# inventory_20150316.xml loading into db complete 2017-07-13 11:57:32.919751
# inventory_20150317.xml loading into db complete 2017-07-13 12:01:52.250942
# inventory_20150318.xml loading into db complete 2017-07-13 12:06:19.525849
# inventory_20150319.xml loading into db complete 2017-07-13 12:10:31.421554
# inventory_20150320.xml loading into db complete 2017-07-13 12:14:48.289991
# inventory_20150321.xml loading into db complete 2017-07-13 12:18:59.264890
# inventory_20150322.xml loading into db complete 2017-07-13 12:23:16.706584
# inventory_20150323.xml loading into db complete 2017-07-13 12:27:35.265014
# inventory_20150324.xml loading into db complete 2017-07-13 12:31:57.916007
# inventory_20150325.xml loading into db complete 2017-07-13 12:36:16.717136
# inventory_20150326.xml loading into db complete 2017-07-13 12:40:33.155369
# inventory_20150327.xml loading into db complete 2017-07-13 12:44:51.363045
# inventory_20150328.xml loading into db complete 2017-07-13 12:49:11.160807
# inventory_20150329.xml loading into db complete 2017-07-13 12:53:24.637219
# inventory_20150330.xml loading into db complete 2017-07-13 12:57:48.080668
# inventory_20150331.xml loading into db complete 2017-07-13 13:02:22.317622
# inventory_20150401.xml loading into db complete 2017-07-13 13:06:56.203357
# inventory_20150402.xml loading into db complete 2017-07-13 13:11:28.578502
# inventory_20150403.xml loading into db complete 2017-07-13 13:15:51.324231
# inventory_20150404.xml loading into db complete 2017-07-13 13:20:21.365481
# inventory_20150405.xml loading into db complete 2017-07-13 13:24:47.569476
# inventory_20150406.xml loading into db complete 2017-07-13 13:29:19.549995
# inventory_20150407.xml loading into db complete 2017-07-13 13:34:03.687467
# inventory_20150408.xml loading into db complete 2017-07-13 13:38:32.634166
# inventory_20150409.xml loading into db complete 2017-07-13 13:43:01.426579
# inventory_20150410.xml loading into db complete 2017-07-13 13:47:28.526649
# inventory_20150411.xml loading into db complete 2017-07-13 13:51:53.880391
# inventory_20150412.xml loading into db complete 2017-07-13 13:56:26.284769
# inventory_20150413.xml loading into db complete 2017-07-13 14:01:02.221634
# inventory_20150414.xml loading into db complete 2017-07-13 14:06:11.786559
# inventory_20150415.xml loading into db complete 2017-07-13 14:12:22.913963
# inventory_20150416.xml loading into db complete 2017-07-13 14:18:20.321179
# inventory_20150417.xml loading into db complete 2017-07-13 14:24:03.400459
# inventory_20150418.xml loading into db complete 2017-07-13 14:29:42.538460
# inventory_20150419.xml loading into db complete 2017-07-13 14:35:04.753071
# inventory_20150420.xml loading into db complete 2017-07-13 14:40:19.886463
# inventory_20150421.xml loading into db complete 2017-07-13 14:45:39.564608
# inventory_20150422.xml loading into db complete 2017-07-13 14:50:53.100101
# inventory_20150423.xml loading into db complete 2017-07-13 14:55:59.302830
# inventory_20150424.xml loading into db complete 2017-07-13 15:01:01.142359
# inventory_20150425.xml loading into db complete 2017-07-13 15:06:22.911564
# inventory_20150426.xml loading into db complete 2017-07-13 15:11:36.406742
# inventory_20150427.xml loading into db complete 2017-07-13 15:16:46.209939
# inventory_20150428.xml loading into db complete 2017-07-13 15:22:09.115943
# inventory_20150429.xml loading into db complete 2017-07-13 15:27:18.723552
# inventory_20150430.xml loading into db complete 2017-07-13 15:32:41.125613
# inventory_20150501.xml loading into db complete 2017-07-13 15:38:04.405282
# inventory_20150502.xml loading into db complete 2017-07-13 15:43:12.241312
# inventory_20150503.xml loading into db complete 2017-07-13 15:48:15.411368
# inventory_20150504.xml loading into db complete 2017-07-13 15:53:21.682461
# inventory_20150505.xml loading into db complete 2017-07-13 15:58:26.881987
# inventory_20150506.xml loading into db complete 2017-07-13 16:03:32.097544
# inventory_20150507.xml loading into db complete 2017-07-13 16:08:35.720054
# inventory_20150508.xml loading into db complete 2017-07-13 16:13:36.789762
# inventory_20150509.xml loading into db complete 2017-07-13 16:18:31.629885
# inventory_20150510.xml loading into db complete 2017-07-13 16:23:28.226744
# inventory_20150511.xml loading into db complete 2017-07-13 16:28:25.281086
# inventory_20150512.xml loading into db complete 2017-07-13 16:33:29.367849
# inventory_20150513.xml loading into db complete 2017-07-13 16:38:20.570279
# inventory_20150514.xml loading into db complete 2017-07-13 16:43:18.090768
# inventory_20150515.xml loading into db complete 2017-07-13 16:48:09.796808
# inventory_20150516.xml loading into db complete 2017-07-13 16:53:01.079270
# inventory_20150517.xml loading into db complete 2017-07-13 16:57:49.888696
# inventory_20150518.xml loading into db complete 2017-07-13 17:02:38.720614
# inventory_20150519.xml loading into db complete 2017-07-13 17:07:52.199447
# inventory_20150520.xml loading into db complete 2017-07-13 17:15:00.555893
# inventory_20150521.xml loading into db complete 2017-07-13 17:22:08.885778
# inventory_20150522.xml loading into db complete 2017-07-13 17:29:37.064892
# inventory_20150523.xml loading into db complete 2017-07-13 17:36:39.271002
# inventory_20150524.xml loading into db complete 2017-07-13 17:43:25.498944
# inventory_20150525.xml loading into db complete 2017-07-13 17:50:45.005699
# inventory_20150526.xml loading into db complete 2017-07-13 17:57:48.031648
# inventory_20150527.xml loading into db complete 2017-07-13 18:05:03.290307
# inventory_20150528.xml loading into db complete 2017-07-13 18:12:33.767688
# inventory_20150529.xml loading into db complete 2017-07-13 18:20:05.323034
# inventory_20150530.xml loading into db complete 2017-07-13 18:27:16.291575
# inventory_20150531.xml loading into db complete 2017-07-13 18:37:14.085119
# inventory_20150601.xml loading into db complete 2017-07-13 18:44:59.460766
# inventory_20150602.xml loading into db complete 2017-07-13 18:52:03.075135
# inventory_20150603.xml loading into db complete 2017-07-13 18:59:11.987778
# inventory_20150604.xml loading into db complete 2017-07-13 19:06:33.025476
# inventory_20150605.xml loading into db complete 2017-07-13 19:13:34.570117
# inventory_20150606.xml loading into db complete 2017-07-13 19:21:09.022999
# inventory_20150607.xml loading into db complete 2017-07-13 19:28:16.355151
# inventory_20150608.xml loading into db complete 2017-07-13 19:35:17.878352
# inventory_20150609.xml loading into db complete 2017-07-13 19:42:10.195919
# inventory_20150610.xml loading into db complete 2017-07-13 19:49:05.135911
# inventory_20150611.xml loading into db complete 2017-07-13 19:56:09.945666
# inventory_20150612.xml loading into db complete 2017-07-13 20:03:32.288568
# inventory_20150613.xml loading into db complete 2017-07-13 20:10:44.759017
# inventory_20150614.xml loading into db complete 2017-07-13 20:17:35.290629
# inventory_20150615.xml loading into db complete 2017-07-13 20:24:39.696756
# inventory_20150616.xml loading into db complete 2017-07-13 20:31:34.738153
# inventory_20150617.xml loading into db complete 2017-07-13 20:38:45.484596
# inventory_20150618.xml loading into db complete 2017-07-13 20:45:47.159871
# inventory_20150619.xml loading into db complete 2017-07-13 20:52:47.922428
# inventory_20150620.xml loading into db complete 2017-07-13 20:59:55.833361
# inventory_20150621.xml loading into db complete 2017-07-13 21:08:20.041438
# inventory_20150622.xml loading into db complete 2017-07-13 21:15:11.020707
# inventory_20150623.xml loading into db complete 2017-07-13 21:22:08.864547
# inventory_20150624.xml loading into db complete 2017-07-13 21:29:10.216442
# inventory_20150625.xml loading into db complete 2017-07-13 21:36:11.619193
# inventory_20150626.xml loading into db complete 2017-07-13 21:43:20.808472
# inventory_20150627.xml loading into db complete 2017-07-13 21:50:14.276361
# inventory_20150628.xml loading into db complete 2017-07-13 21:56:59.214128
# inventory_20150629.xml loading into db complete 2017-07-13 22:05:03.722557
# inventory_20150630.xml loading into db complete 2017-07-13 22:13:31.881385

# %%
# Out:
# 2017-07-12 22:44:35.216045
